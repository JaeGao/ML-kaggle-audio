# %%
# Block 1: Importing Libraries
import tarfile
import resampy
import pandas as pd
import librosa
import numpy as np
import os
import shutil
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from concurrent.futures import ThreadPoolExecutor
from torch.optim.lr_scheduler import CosineAnnealingLR
import albumentations as A
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
else:
    print("No GPU available. Training will run on CPU.")
# Out:
# GPU: NVIDIA GeForce RTX 4080 Laptop GPU is available.

# %%
# Block 2: Extracting Data
def extract_tar(tar_file, target_dir):
    if os.path.exists(target_dir):
        user_input = input(f"The directory '{target_dir}' already exists. Do you want to skip extraction? (y/n): ")
        if user_input.lower() == 'y':
            print(f"Skipping extraction of {tar_file}.")
            return
        else:
            print(f"Overwriting the existing directory '{target_dir}'.")
            shutil.rmtree(target_dir)
    with tarfile.open(tar_file, 'r') as tar:
        tar.extractall(target_dir)
    # Remove residue "._" hidden files from the inner folder
    inner_folder = os.path.join(target_dir, os.path.splitext(os.path.basename(tar_file))[0])
    for root, dirs, files in os.walk(inner_folder):
        for file in files:
            if file.startswith("._"):
                os.remove(os.path.join(root, file))

extract_tar('train_mp3s.tar', 'train_mp3s')
extract_tar('test_mp3s.tar', 'test_mp3s')
train_labels = np.loadtxt('train_label.txt', dtype=int)
# Out:
# Skipping extraction of train_mp3s.tar.
# Skipping extraction of test_mp3s.tar.

# %%
# Block 3: Preprocessing Functions

import pickle

def save_preprocessed_data(data, labels, folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    with open(os.path.join(folder_path, 'train_features.pkl'), 'wb') as f:
        pickle.dump(data, f)

    with open(os.path.join(folder_path, 'train_labels.pkl'), 'wb') as f:
        pickle.dump(labels, f)

def load_preprocessed_data(folder_path):
    with open(os.path.join(folder_path, 'train_features.pkl'), 'rb') as f:
        data = pickle.load(f)

    with open(os.path.join(folder_path, 'train_labels.pkl'), 'rb') as f:
        labels = pickle.load(f)

    return data, labels
def preprocess_audio(file_path, augment=False):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
        print(f"Loaded audio file: {file_path}")

        # Apply audio augmentation
        if augment:
            audio = apply_audio_augmentation(audio, sample_rate)

        # Extract MFCC features
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)

        # Extract additional features
        spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sample_rate)
        tonnetz = librosa.feature.tonnetz(y=audio, sr=sample_rate)
        chroma_stft = librosa.feature.chroma_stft(y=audio, sr=sample_rate)
        chroma_cqt = librosa.feature.chroma_cqt(y=audio, sr=sample_rate)
        chroma_cens = librosa.feature.chroma_cens(y=audio, sr=sample_rate)

        # Concatenate features
        features = np.concatenate((mfccs, spectral_contrast, tonnetz, chroma_stft, chroma_cqt, chroma_cens), axis=0)

        features_scaled = np.mean(features.T, axis=0)
        print(f"Extracted features: {features_scaled.shape}")
        return features_scaled
    except Exception as e:
        print(f"Error processing file: {file_path}")
        print(f"Error message: {str(e)}")
        return None

def apply_audio_augmentation(audio, sample_rate):
    # Apply pitch shifting
    pitch_shift = np.random.randint(-2, 2)
    audio = librosa.effects.pitch_shift(audio, sr=sample_rate, n_steps=pitch_shift)

    # Apply time stretching
    stretch_factor = np.random.uniform(0.8, 1.2)
    audio = librosa.effects.time_stretch(audio, rate=stretch_factor)

    # Apply noise injection
    noise_amp = 0.005 * np.random.uniform(0, 1)
    noise = noise_amp * np.random.normal(size=audio.shape[0])
    audio = audio + noise

    return audio

def process_file(file_path, augment=False):
    print(f"Processing file: {file_path}")
    features = preprocess_audio(file_path, augment=augment)
    return features

def prepare_data(directory, augment=False):
    file_paths = [os.path.join(directory, f"{i}.mp3") for i in range(len(os.listdir(directory)))]
    with ThreadPoolExecutor() as executor:
        results = list(executor.map(lambda x: process_file(x, augment), file_paths))
    features = [feat for feat in results if feat is not None]
    print(f"Processed {len(features)} audio files")
    return np.array(features)

# %%
# Block 4: Preparing Data (modified)
folder_path = 'V5'

try:
    train_features, train_labels = load_preprocessed_data(folder_path)
    print("Loaded preprocessed data from the 'V5' folder.")
except FileNotFoundError:
    train_features_original = prepare_data('train_mp3s/train_mp3s')
    print(f"Original train features shape: {train_features_original.shape}")

    train_features_augmented = prepare_data('train_mp3s/train_mp3s', augment=True)
    print(f"Augmented train features shape: {train_features_augmented.shape}")

    train_features = np.concatenate((train_features_original, train_features_augmented), axis=0)
    print(f"Combined train features shape: {train_features.shape}")

    test_features = prepare_data('test_mp3s/test_mp3s')
    print(f"Test features shape: {test_features.shape}")

    label_encoder = LabelEncoder()
    train_labels_original = label_encoder.fit_transform(train_labels)
    train_labels_augmented = train_labels_original.copy()
    train_labels = np.concatenate((train_labels_original, train_labels_augmented), axis=0)
    print(f"Train labels shape: {train_labels.shape}")

    print(f"Number of training features: {len(train_features)}")
    print(f"Number of training labels: {len(train_labels)}")
    print(f"Number of test features: {len(test_features)}")

    save_preprocessed_data(train_features, train_labels, folder_path)
    print("Saved preprocessed data to the 'V5' folder.")

if len(train_features) == 0:
    print("No training features available. Please check the data.")
# Out:
# Processing file: train_mp3s/train_mp3s\0.mp3
# Processing file: train_mp3s/train_mp3s\1.mp3
# Processing file: train_mp3s/train_mp3s\2.mp3
# Processing file: train_mp3s/train_mp3s\3.mp3
# Processing file: train_mp3s/train_mp3s\4.mp3
# Processing file: train_mp3s/train_mp3s\5.mp3
# Processing file: train_mp3s/train_mp3s\6.mp3
# Processing file: train_mp3s/train_mp3s\7.mp3
# Processing file: train_mp3s/train_mp3s\8.mp3
# Processing file: train_mp3s/train_mp3s\9.mp3
# Processing file: train_mp3s/train_mp3s\10.mp3
# Processing file: train_mp3s/train_mp3s\11.mp3
# Processing file: train_mp3s/train_mp3s\12.mp3
# Processing file: train_mp3s/train_mp3s\13.mp3
# Processing file: train_mp3s/train_mp3s\14.mp3
# Processing file: train_mp3s/train_mp3s\15.mp3
# Processing file: train_mp3s/train_mp3s\16.mp3
# Loaded audio file: train_mp3s/train_mp3s\0.mp3
# Loaded audio file: train_mp3s/train_mp3s\1.mp3
# Processing file: train_mp3s/train_mp3s\17.mp3
# Processing file: train_mp3s/train_mp3s\18.mp3
# Loaded audio file: train_mp3s/train_mp3s\3.mp3
# Loaded audio file: train_mp3s/train_mp3s\2.mp3
# Loaded audio file: train_mp3s/train_mp3s\6.mp3
# Loaded audio file: train_mp3s/train_mp3s\4.mp3
# Loaded audio file: train_mp3s/train_mp3s\5.mp3
# Loaded audio file: train_mp3s/train_mp3s\7.mp3
# Processing file: train_mp3s/train_mp3s\19.mp3
# Loaded audio file: train_mp3s/train_mp3s\10.mp3
# Loaded audio file: train_mp3s/train_mp3s\8.mp3
# Loaded audio file: train_mp3s/train_mp3s\9.mp3
# Loaded audio file: train_mp3s/train_mp3s\11.mp3
# Loaded audio file: train_mp3s/train_mp3s\13.mp3
# Loaded audio file: train_mp3s/train_mp3s\12.mp3
# Loaded audio file: train_mp3s/train_mp3s\14.mp3
# Loaded audio file: train_mp3s/train_mp3s\16.mp3
# Loaded audio file: train_mp3s/train_mp3s\15.mp3
# Loaded audio file: train_mp3s/train_mp3s\18.mp3
# Loaded audio file: train_mp3s/train_mp3s\17.mp3
# Loaded audio file: train_mp3s/train_mp3s\19.mp3
# Processing file: train_mp3s/train_mp3s\20.mp3
# Processing file: train_mp3s/train_mp3s\21.mp3
# Loaded audio file: train_mp3s/train_mp3s\20.mp3
# Loaded audio file: train_mp3s/train_mp3s\21.mp3
# Processing file: train_mp3s/train_mp3s\22.mp3
# Processing file: train_mp3s/train_mp3s\23.mp3
# Processing file: train_mp3s/train_mp3s\24.mp3
# Processing file: train_mp3s/train_mp3s\25.mp3
# Loaded audio file: train_mp3s/train_mp3s\22.mp3
# Processing file: train_mp3s/train_mp3s\26.mp3
# Loaded audio file: train_mp3s/train_mp3s\23.mp3
# Loaded audio file: train_mp3s/train_mp3s\24.mp3
# Loaded audio file: train_mp3s/train_mp3s\25.mp3
# Loaded audio file: train_mp3s/train_mp3s\26.mp3
# Processing file: train_mp3s/train_mp3s\27.mp3
# Processing file: train_mp3s/train_mp3s\28.mp3
# Processing file: train_mp3s/train_mp3s\29.mp3
# Processing file: train_mp3s/train_mp3s\30.mp3
# Loaded audio file: train_mp3s/train_mp3s\27.mp3
# Loaded audio file: train_mp3s/train_mp3s\30.mp3
# Loaded audio file: train_mp3s/train_mp3s\29.mp3
# Loaded audio file: train_mp3s/train_mp3s\28.mp3
# Processing file: train_mp3s/train_mp3s\31.mp3
# Loaded audio file: train_mp3s/train_mp3s\31.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\32.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\33.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\34.mp3
# Loaded audio file: train_mp3s/train_mp3s\32.mp3
# Loaded audio file: train_mp3s/train_mp3s\33.mp3
# Loaded audio file: train_mp3s/train_mp3s\34.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\35.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\36.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\37.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\38.mp3
# Loaded audio file: train_mp3s/train_mp3s\35.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\39.mp3
# Loaded audio file: train_mp3s/train_mp3s\37.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\40.mp3
# Loaded audio file: train_mp3s/train_mp3s\38.mp3
# Loaded audio file: train_mp3s/train_mp3s\36.mp3
# Loaded audio file: train_mp3s/train_mp3s\39.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\41.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\42.mp3
# Loaded audio file: train_mp3s/train_mp3s\40.mp3
# Loaded audio file: train_mp3s/train_mp3s\41.mp3
# Loaded audio file: train_mp3s/train_mp3s\42.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\43.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\44.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\45.mp3
# Loaded audio file: train_mp3s/train_mp3s\44.mp3
# Loaded audio file: train_mp3s/train_mp3s\43.mp3
# Loaded audio file: train_mp3s/train_mp3s\45.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\46.mp3
# Loaded audio file: train_mp3s/train_mp3s\46.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\47.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\48.mp3
# Loaded audio file: train_mp3s/train_mp3s\47.mp3
# Loaded audio file: train_mp3s/train_mp3s\48.mp3
# Extracted features: (89,)Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\49.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\50.mp3
#
# Processing file: train_mp3s/train_mp3s\51.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\52.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\53.mp3
# Loaded audio file: train_mp3s/train_mp3s\51.mp3
# Loaded audio file: train_mp3s/train_mp3s\50.mp3
# Loaded audio file: train_mp3s/train_mp3s\49.mp3
# Loaded audio file: train_mp3s/train_mp3s\52.mp3
# Loaded audio file: train_mp3s/train_mp3s\53.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\54.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\55.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\56.mp3
# Loaded audio file: train_mp3s/train_mp3s\54.mp3
# Loaded audio file: train_mp3s/train_mp3s\55.mp3
# Loaded audio file: train_mp3s/train_mp3s\56.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\57.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\58.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\59.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\60.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\61.mp3
# Loaded audio file: train_mp3s/train_mp3s\57.mp3
# Loaded audio file: train_mp3s/train_mp3s\58.mp3
# Loaded audio file: train_mp3s/train_mp3s\59.mp3
# Loaded audio file: train_mp3s/train_mp3s\60.mp3
# Loaded audio file: train_mp3s/train_mp3s\61.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\62.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\63.mp3
# Loaded audio file: train_mp3s/train_mp3s\62.mp3
# Loaded audio file: train_mp3s/train_mp3s\63.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\64.mp3
# Loaded audio file: train_mp3s/train_mp3s\64.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\65.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\66.mp3
# Loaded audio file: train_mp3s/train_mp3s\65.mp3
# Loaded audio file: train_mp3s/train_mp3s\66.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\67.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\68.mp3
# Loaded audio file: train_mp3s/train_mp3s\67.mp3
# Loaded audio file: train_mp3s/train_mp3s\68.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\69.mp3
# Loaded audio file: train_mp3s/train_mp3s\69.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\70.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\71.mp3
# Loaded audio file: train_mp3s/train_mp3s\70.mp3
# Loaded audio file: train_mp3s/train_mp3s\71.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\72.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\73.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\74.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\75.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\76.mp3
# Loaded audio file: train_mp3s/train_mp3s\74.mp3
# Loaded audio file: train_mp3s/train_mp3s\72.mp3
# Loaded audio file: train_mp3s/train_mp3s\73.mp3
# Loaded audio file: train_mp3s/train_mp3s\75.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\77.mp3
# Loaded audio file: train_mp3s/train_mp3s\76.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\78.mp3
# Loaded audio file: train_mp3s/train_mp3s\77.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\79.mp3
# Loaded audio file: train_mp3s/train_mp3s\78.mp3
# Loaded audio file: train_mp3s/train_mp3s\79.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\80.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\81.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\82.mp3
# Loaded audio file: train_mp3s/train_mp3s\80.mp3
# Loaded audio file: train_mp3s/train_mp3s\81.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\83.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\84.mp3
# Loaded audio file: train_mp3s/train_mp3s\82.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\85.mp3
# Loaded audio file: train_mp3s/train_mp3s\83.mp3
# Loaded audio file: train_mp3s/train_mp3s\84.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\86.mp3
# Loaded audio file: train_mp3s/train_mp3s\85.mp3
# Loaded audio file: train_mp3s/train_mp3s\86.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\87.mp3
# Loaded audio file: train_mp3s/train_mp3s\87.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\88.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\89.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\90.mp3
# Loaded audio file: train_mp3s/train_mp3s\88.mp3
# Loaded audio file: train_mp3s/train_mp3s\90.mp3
# Loaded audio file: train_mp3s/train_mp3s\89.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\91.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\92.mp3
# Loaded audio file: train_mp3s/train_mp3s\91.mp3Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\93.mp3
#
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\94.mp3
# Loaded audio file: train_mp3s/train_mp3s\92.mp3
# Loaded audio file: train_mp3s/train_mp3s\94.mp3
# Loaded audio file: train_mp3s/train_mp3s\93.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\95.mp3
# Loaded audio file: train_mp3s/train_mp3s\95.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\96.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\97.mp3
# Loaded audio file: train_mp3s/train_mp3s\96.mp3
# Loaded audio file: train_mp3s/train_mp3s\97.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\98.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\99.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\100.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\101.mp3
# Loaded audio file: train_mp3s/train_mp3s\99.mp3
# Loaded audio file: train_mp3s/train_mp3s\98.mp3
# Loaded audio file: train_mp3s/train_mp3s\100.mp3
# Loaded audio file: train_mp3s/train_mp3s\101.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\102.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\103.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\104.mp3
# Loaded audio file: train_mp3s/train_mp3s\102.mp3
# Loaded audio file: train_mp3s/train_mp3s\103.mp3
# Loaded audio file: train_mp3s/train_mp3s\104.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\105.mp3
# Loaded audio file: train_mp3s/train_mp3s\105.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\106.mp3
# Extracted features: (89,)Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\107.mp3
#
# Processing file: train_mp3s/train_mp3s\108.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\109.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\110.mp3
# Loaded audio file: train_mp3s/train_mp3s\108.mp3
# Loaded audio file: train_mp3s/train_mp3s\106.mp3
# Loaded audio file: train_mp3s/train_mp3s\107.mp3
# Loaded audio file: train_mp3s/train_mp3s\109.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\111.mp3
# Loaded audio file: train_mp3s/train_mp3s\110.mp3
# Loaded audio file: train_mp3s/train_mp3s\111.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\112.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\113.mp3
# Loaded audio file: train_mp3s/train_mp3s\113.mp3
# Loaded audio file: train_mp3s/train_mp3s\112.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\114.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\115.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\116.mp3
# Loaded audio file: train_mp3s/train_mp3s\114.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\117.mp3
# Loaded audio file: train_mp3s/train_mp3s\115.mp3
# Loaded audio file: train_mp3s/train_mp3s\116.mp3
# Loaded audio file: train_mp3s/train_mp3s\117.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\118.mp3
# Loaded audio file: train_mp3s/train_mp3s\118.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\119.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\120.mp3
# Loaded audio file: train_mp3s/train_mp3s\119.mp3
# Loaded audio file: train_mp3s/train_mp3s\120.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\121.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\122.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\123.mp3
# Loaded audio file: train_mp3s/train_mp3s\121.mp3
# Loaded audio file: train_mp3s/train_mp3s\122.mp3
# Loaded audio file: train_mp3s/train_mp3s\123.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\124.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\125.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\126.mp3
# Loaded audio file: train_mp3s/train_mp3s\124.mp3
# Loaded audio file: train_mp3s/train_mp3s\125.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\127.mp3
# Loaded audio file: train_mp3s/train_mp3s\126.mp3
# Loaded audio file: train_mp3s/train_mp3s\127.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\128.mp3
# Loaded audio file: train_mp3s/train_mp3s\128.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\129.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\130.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\131.mp3
# Loaded audio file: train_mp3s/train_mp3s\129.mp3
# Loaded audio file: train_mp3s/train_mp3s\130.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\132.mp3
# Loaded audio file: train_mp3s/train_mp3s\131.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\133.mp3
# Loaded audio file: train_mp3s/train_mp3s\132.mp3
# Loaded audio file: train_mp3s/train_mp3s\133.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\134.mp3
# Loaded audio file: train_mp3s/train_mp3s\134.mp3
# Extracted features: (89,)Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\135.mp3
#
# Processing file: train_mp3s/train_mp3s\136.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\137.mp3
# Loaded audio file: train_mp3s/train_mp3s\137.mp3
# Loaded audio file: train_mp3s/train_mp3s\135.mp3
# Loaded audio file: train_mp3s/train_mp3s\136.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\138.mp3
# Loaded audio file: train_mp3s/train_mp3s\138.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\139.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\140.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\141.mp3
# Loaded audio file: train_mp3s/train_mp3s\139.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\142.mp3
# Loaded audio file: train_mp3s/train_mp3s\140.mp3
# Loaded audio file: train_mp3s/train_mp3s\141.mp3
# Loaded audio file: train_mp3s/train_mp3s\142.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\143.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\144.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\145.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\146.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\147.mp3
# Loaded audio file: train_mp3s/train_mp3s\144.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\148.mp3
# Loaded audio file: train_mp3s/train_mp3s\145.mp3
# Loaded audio file: train_mp3s/train_mp3s\143.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\149.mp3
# Loaded audio file: train_mp3s/train_mp3s\146.mp3
# Loaded audio file: train_mp3s/train_mp3s\148.mp3
# Loaded audio file: train_mp3s/train_mp3s\147.mp3
# Loaded audio file: train_mp3s/train_mp3s\149.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\150.mp3
# Loaded audio file: train_mp3s/train_mp3s\150.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\151.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\152.mp3
# Loaded audio file: train_mp3s/train_mp3s\151.mp3
# Loaded audio file: train_mp3s/train_mp3s\152.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\153.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\154.mp3
# Loaded audio file: train_mp3s/train_mp3s\153.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\155.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\156.mp3
# Loaded audio file: train_mp3s/train_mp3s\154.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\157.mp3
# Loaded audio file: train_mp3s/train_mp3s\155.mp3
# Loaded audio file: train_mp3s/train_mp3s\156.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\158.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\159.mp3
# Loaded audio file: train_mp3s/train_mp3s\157.mp3
# Loaded audio file: train_mp3s/train_mp3s\159.mp3
# Loaded audio file: train_mp3s/train_mp3s\158.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\160.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\161.mp3
# Loaded audio file: train_mp3s/train_mp3s\160.mp3
# Loaded audio file: train_mp3s/train_mp3s\161.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\162.mp3
# Loaded audio file: train_mp3s/train_mp3s\162.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\163.mp3
# Loaded audio file: train_mp3s/train_mp3s\163.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\164.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\165.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\166.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\167.mp3
# Loaded audio file: train_mp3s/train_mp3s\165.mp3
# Loaded audio file: train_mp3s/train_mp3s\164.mp3
# Loaded audio file: train_mp3s/train_mp3s\167.mp3
# Loaded audio file: train_mp3s/train_mp3s\166.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\168.mp3
# Extracted features: (89,)Loaded audio file: train_mp3s/train_mp3s\168.mp3
#
# Processing file: train_mp3s/train_mp3s\169.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\170.mp3
# Loaded audio file: train_mp3s/train_mp3s\169.mp3
# Loaded audio file: train_mp3s/train_mp3s\170.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\171.mp3
# Loaded audio file: train_mp3s/train_mp3s\171.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\172.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\173.mp3
# Loaded audio file: train_mp3s/train_mp3s\172.mp3Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\174.mp3
#
# Loaded audio file: train_mp3s/train_mp3s\173.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\175.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\176.mp3
# Loaded audio file: train_mp3s/train_mp3s\174.mp3
# Loaded audio file: train_mp3s/train_mp3s\176.mp3
# Loaded audio file: train_mp3s/train_mp3s\175.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\177.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\178.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\179.mp3
# Loaded audio file: train_mp3s/train_mp3s\177.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\180.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\181.mp3
# Loaded audio file: train_mp3s/train_mp3s\178.mp3
# Loaded audio file: train_mp3s/train_mp3s\179.mp3
# Loaded audio file: train_mp3s/train_mp3s\180.mp3
# Loaded audio file: train_mp3s/train_mp3s\181.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\182.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\183.mp3
# Loaded audio file: train_mp3s/train_mp3s\182.mp3
# Loaded audio file: train_mp3s/train_mp3s\183.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\184.mp3
# Loaded audio file: train_mp3s/train_mp3s\184.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\185.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\186.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\187.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\188.mp3
# Loaded audio file: train_mp3s/train_mp3s\185.mp3
# Loaded audio file: train_mp3s/train_mp3s\187.mp3
# Loaded audio file: train_mp3s/train_mp3s\186.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\189.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\190.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\191.mp3
# Loaded audio file: train_mp3s/train_mp3s\189.mp3
# Loaded audio file: train_mp3s/train_mp3s\188.mp3
# Loaded audio file: train_mp3s/train_mp3s\191.mp3
# Loaded audio file: train_mp3s/train_mp3s\190.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\192.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\193.mp3
# Loaded audio file: train_mp3s/train_mp3s\192.mp3
# Loaded audio file: train_mp3s/train_mp3s\193.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\194.mp3
# Loaded audio file: train_mp3s/train_mp3s\194.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\195.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\196.mp3
# Loaded audio file: train_mp3s/train_mp3s\195.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\197.mp3
# Loaded audio file: train_mp3s/train_mp3s\196.mp3
# Loaded audio file: train_mp3s/train_mp3s\197.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\198.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\199.mp3
# Loaded audio file: train_mp3s/train_mp3s\198.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\200.mp3
# Loaded audio file: train_mp3s/train_mp3s\199.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\201.mp3
# Loaded audio file: train_mp3s/train_mp3s\200.mp3
# Loaded audio file: train_mp3s/train_mp3s\201.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\202.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\203.mp3
# Loaded audio file: train_mp3s/train_mp3s\202.mp3
# Loaded audio file: train_mp3s/train_mp3s\203.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\204.mp3
# Loaded audio file: train_mp3s/train_mp3s\204.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\205.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\206.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\207.mp3
# Loaded audio file: train_mp3s/train_mp3s\205.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\208.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\209.mp3
# Loaded audio file: train_mp3s/train_mp3s\207.mp3
# Loaded audio file: train_mp3s/train_mp3s\209.mp3
# Loaded audio file: train_mp3s/train_mp3s\206.mp3
# Loaded audio file: train_mp3s/train_mp3s\208.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\210.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\211.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\212.mp3
# Loaded audio file: train_mp3s/train_mp3s\210.mp3
# Loaded audio file: train_mp3s/train_mp3s\212.mp3
# Loaded audio file: train_mp3s/train_mp3s\211.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\213.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\214.mp3
# Loaded audio file: train_mp3s/train_mp3s\213.mp3
# Loaded audio file: train_mp3s/train_mp3s\214.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\215.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\216.mp3
# Loaded audio file: train_mp3s/train_mp3s\216.mp3
# Loaded audio file: train_mp3s/train_mp3s\215.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\217.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\218.mp3
# Loaded audio file: train_mp3s/train_mp3s\217.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\219.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\220.mp3
# Loaded audio file: train_mp3s/train_mp3s\218.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\221.mp3
# Loaded audio file: train_mp3s/train_mp3s\219.mp3
# Loaded audio file: train_mp3s/train_mp3s\220.mp3
# Loaded audio file: train_mp3s/train_mp3s\221.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\222.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\223.mp3
# Loaded audio file: train_mp3s/train_mp3s\222.mp3
# Loaded audio file: train_mp3s/train_mp3s\223.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\224.mp3
# Loaded audio file: train_mp3s/train_mp3s\224.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\225.mp3
# Loaded audio file: train_mp3s/train_mp3s\225.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\226.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\227.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\228.mp3
# Loaded audio file: train_mp3s/train_mp3s\226.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\229.mp3
# Loaded audio file: train_mp3s/train_mp3s\227.mp3
# Loaded audio file: train_mp3s/train_mp3s\228.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\230.mp3
# Loaded audio file: train_mp3s/train_mp3s\229.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\231.mp3
# Loaded audio file: train_mp3s/train_mp3s\230.mp3
# Loaded audio file: train_mp3s/train_mp3s\231.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\232.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\233.mp3
# Loaded audio file: train_mp3s/train_mp3s\232.mp3
# Loaded audio file: train_mp3s/train_mp3s\233.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\234.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\235.mp3
# Loaded audio file: train_mp3s/train_mp3s\234.mp3
# Loaded audio file: train_mp3s/train_mp3s\235.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\236.mp3
# Loaded audio file: train_mp3s/train_mp3s\236.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\237.mp3
# Loaded audio file: train_mp3s/train_mp3s\237.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\238.mp3
# Loaded audio file: train_mp3s/train_mp3s\238.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\239.mp3
# Loaded audio file: train_mp3s/train_mp3s\239.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\240.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\241.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\242.mp3
# Loaded audio file: train_mp3s/train_mp3s\240.mp3
# Loaded audio file: train_mp3s/train_mp3s\241.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\243.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\244.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\245.mp3
# Loaded audio file: train_mp3s/train_mp3s\242.mp3
# Loaded audio file: train_mp3s/train_mp3s\243.mp3
# Loaded audio file: train_mp3s/train_mp3s\244.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\246.mp3
# Loaded audio file: train_mp3s/train_mp3s\245.mp3
# Loaded audio file: train_mp3s/train_mp3s\246.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\247.mp3
# Loaded audio file: train_mp3s/train_mp3s\247.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\248.mp3
# Loaded audio file: train_mp3s/train_mp3s\248.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\249.mp3
# Loaded audio file: train_mp3s/train_mp3s\249.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\250.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\251.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\252.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\253.mp3
# Loaded audio file: train_mp3s/train_mp3s\250.mp3
# Loaded audio file: train_mp3s/train_mp3s\251.mp3
# Loaded audio file: train_mp3s/train_mp3s\252.mp3
# Loaded audio file: train_mp3s/train_mp3s\253.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\254.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\255.mp3
# Loaded audio file: train_mp3s/train_mp3s\254.mp3
# Loaded audio file: train_mp3s/train_mp3s\255.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\256.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\257.mp3
# Loaded audio file: train_mp3s/train_mp3s\256.mp3
# Loaded audio file: train_mp3s/train_mp3s\257.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\258.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\259.mp3
# Loaded audio file: train_mp3s/train_mp3s\259.mp3
# Loaded audio file: train_mp3s/train_mp3s\258.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\260.mp3
# Loaded audio file: train_mp3s/train_mp3s\260.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\261.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\262.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\263.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\264.mp3
# Loaded audio file: train_mp3s/train_mp3s\261.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\265.mp3
# Loaded audio file: train_mp3s/train_mp3s\262.mp3
# Loaded audio file: train_mp3s/train_mp3s\263.mp3
# Loaded audio file: train_mp3s/train_mp3s\264.mp3
# Loaded audio file: train_mp3s/train_mp3s\265.mp3
# Extracted features: (89,)Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\266.mp3
#
# Processing file: train_mp3s/train_mp3s\267.mp3
# Loaded audio file: train_mp3s/train_mp3s\266.mp3
# Loaded audio file: train_mp3s/train_mp3s\267.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\268.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\269.mp3
# Loaded audio file: train_mp3s/train_mp3s\268.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\270.mp3
# Loaded audio file: train_mp3s/train_mp3s\269.mp3
# Loaded audio file: train_mp3s/train_mp3s\270.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\271.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\272.mp3
# Loaded audio file: train_mp3s/train_mp3s\271.mp3
# Loaded audio file: train_mp3s/train_mp3s\272.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\273.mp3
# Loaded audio file: train_mp3s/train_mp3s\273.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\274.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\275.mp3
# Loaded audio file: train_mp3s/train_mp3s\275.mp3
# Loaded audio file: train_mp3s/train_mp3s\274.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\276.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\277.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\278.mp3
# Loaded audio file: train_mp3s/train_mp3s\277.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\279.mp3
# Loaded audio file: train_mp3s/train_mp3s\276.mp3
# Loaded audio file: train_mp3s/train_mp3s\278.mp3
# Loaded audio file: train_mp3s/train_mp3s\279.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\280.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\281.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\282.mp3
# Loaded audio file: train_mp3s/train_mp3s\280.mp3
# Loaded audio file: train_mp3s/train_mp3s\281.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\283.mp3
# Loaded audio file: train_mp3s/train_mp3s\282.mp3
# Loaded audio file: train_mp3s/train_mp3s\283.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\284.mp3
# Loaded audio file: train_mp3s/train_mp3s\284.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\285.mp3
# Loaded audio file: train_mp3s/train_mp3s\285.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\286.mp3
# Loaded audio file: train_mp3s/train_mp3s\286.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\287.mp3
# Loaded audio file: train_mp3s/train_mp3s\287.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\288.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\289.mp3
# Loaded audio file: train_mp3s/train_mp3s\288.mp3
# Loaded audio file: train_mp3s/train_mp3s\289.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\290.mp3
# Loaded audio file: train_mp3s/train_mp3s\290.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\291.mp3
# Loaded audio file: train_mp3s/train_mp3s\291.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\292.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\293.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\294.mp3
# Loaded audio file: train_mp3s/train_mp3s\292.mp3
# Loaded audio file: train_mp3s/train_mp3s\293.mp3
# Loaded audio file: train_mp3s/train_mp3s\294.mp3
# Extracted features: (89,)Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\295.mp3
#
# Processing file: train_mp3s/train_mp3s\296.mp3
# Loaded audio file: train_mp3s/train_mp3s\296.mp3
# Loaded audio file: train_mp3s/train_mp3s\295.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\297.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\298.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\299.mp3
# Loaded audio file: train_mp3s/train_mp3s\297.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\300.mp3
# Loaded audio file: train_mp3s/train_mp3s\298.mp3
# Loaded audio file: train_mp3s/train_mp3s\299.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\301.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\302.mp3
# Loaded audio file: train_mp3s/train_mp3s\300.mp3
# Loaded audio file: train_mp3s/train_mp3s\301.mp3
# Loaded audio file: train_mp3s/train_mp3s\302.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\303.mp3
# Loaded audio file: train_mp3s/train_mp3s\303.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\304.mp3
# Loaded audio file: train_mp3s/train_mp3s\304.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\305.mp3
# Loaded audio file: train_mp3s/train_mp3s\305.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\306.mp3
# Loaded audio file: train_mp3s/train_mp3s\306.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\307.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\308.mp3
# Loaded audio file: train_mp3s/train_mp3s\307.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\309.mp3
# Loaded audio file: train_mp3s/train_mp3s\308.mp3
# Loaded audio file: train_mp3s/train_mp3s\309.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\310.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\311.mp3
# Loaded audio file: train_mp3s/train_mp3s\310.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\312.mp3
# Loaded audio file: train_mp3s/train_mp3s\311.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\313.mp3
# Loaded audio file: train_mp3s/train_mp3s\312.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\314.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\315.mp3
# Loaded audio file: train_mp3s/train_mp3s\313.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\316.mp3
# Loaded audio file: train_mp3s/train_mp3s\314.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\317.mp3
# Loaded audio file: train_mp3s/train_mp3s\316.mp3
# Loaded audio file: train_mp3s/train_mp3s\315.mp3
# Loaded audio file: train_mp3s/train_mp3s\317.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\318.mp3
# Loaded audio file: train_mp3s/train_mp3s\318.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\319.mp3
# Loaded audio file: train_mp3s/train_mp3s\319.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\320.mp3
# Loaded audio file: train_mp3s/train_mp3s\320.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\321.mp3
# Loaded audio file: train_mp3s/train_mp3s\321.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\322.mp3
# Loaded audio file: train_mp3s/train_mp3s\322.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\323.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\324.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\325.mp3
# Loaded audio file: train_mp3s/train_mp3s\323.mp3
# Loaded audio file: train_mp3s/train_mp3s\324.mp3
# Loaded audio file: train_mp3s/train_mp3s\325.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\326.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\327.mp3
# Loaded audio file: train_mp3s/train_mp3s\326.mp3
# Loaded audio file: train_mp3s/train_mp3s\327.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\328.mp3
# Loaded audio file: train_mp3s/train_mp3s\328.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\329.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\330.mp3
# Loaded audio file: train_mp3s/train_mp3s\330.mp3
# Loaded audio file: train_mp3s/train_mp3s\329.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\331.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\332.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\333.mp3
# Loaded audio file: train_mp3s/train_mp3s\331.mp3
# Loaded audio file: train_mp3s/train_mp3s\332.mp3
# Loaded audio file: train_mp3s/train_mp3s\333.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\334.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\335.mp3
# Loaded audio file: train_mp3s/train_mp3s\334.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\336.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\337.mp3
# Loaded audio file: train_mp3s/train_mp3s\335.mp3
# Loaded audio file: train_mp3s/train_mp3s\336.mp3
# Loaded audio file: train_mp3s/train_mp3s\337.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\338.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\339.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\340.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\341.mp3
# Loaded audio file: train_mp3s/train_mp3s\338.mp3
# Loaded audio file: train_mp3s/train_mp3s\340.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\342.mp3
# Loaded audio file: train_mp3s/train_mp3s\339.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\343.mp3
# Loaded audio file: train_mp3s/train_mp3s\341.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\344.mp3
# Loaded audio file: train_mp3s/train_mp3s\342.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\345.mp3
# Loaded audio file: train_mp3s/train_mp3s\343.mp3
# Loaded audio file: train_mp3s/train_mp3s\344.mp3
# Loaded audio file: train_mp3s/train_mp3s\345.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\346.mp3
# Loaded audio file: train_mp3s/train_mp3s\346.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\347.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\348.mp3
# Loaded audio file: train_mp3s/train_mp3s\347.mp3
# Loaded audio file: train_mp3s/train_mp3s\348.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\349.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\350.mp3
# Loaded audio file: train_mp3s/train_mp3s\349.mp3
# Loaded audio file: train_mp3s/train_mp3s\350.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\351.mp3
# Loaded audio file: train_mp3s/train_mp3s\351.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\352.mp3
# Loaded audio file: train_mp3s/train_mp3s\352.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\353.mp3
# Loaded audio file: train_mp3s/train_mp3s\353.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\354.mp3
# Loaded audio file: train_mp3s/train_mp3s\354.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\355.mp3
# Loaded audio file: train_mp3s/train_mp3s\355.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\356.mp3
# Loaded audio file: train_mp3s/train_mp3s\356.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\357.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\358.mp3
# Loaded audio file: train_mp3s/train_mp3s\357.mp3
# Loaded audio file: train_mp3s/train_mp3s\358.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\359.mp3
# Loaded audio file: train_mp3s/train_mp3s\359.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\360.mp3
# Loaded audio file: train_mp3s/train_mp3s\360.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\361.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\362.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\363.mp3
# Loaded audio file: train_mp3s/train_mp3s\361.mp3
# Loaded audio file: train_mp3s/train_mp3s\362.mp3
# Loaded audio file: train_mp3s/train_mp3s\363.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\364.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\365.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\366.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\367.mp3
# Loaded audio file: train_mp3s/train_mp3s\364.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\368.mp3
# Loaded audio file: train_mp3s/train_mp3s\365.mp3
# Loaded audio file: train_mp3s/train_mp3s\367.mp3
# Loaded audio file: train_mp3s/train_mp3s\366.mp3
# Loaded audio file: train_mp3s/train_mp3s\368.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\369.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\370.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\371.mp3
# Extracted features: (89,)Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\372.mp3
#
# Processing file: train_mp3s/train_mp3s\373.mp3
# Loaded audio file: train_mp3s/train_mp3s\369.mp3
# Loaded audio file: train_mp3s/train_mp3s\370.mp3
# Loaded audio file: train_mp3s/train_mp3s\371.mp3
# Loaded audio file: train_mp3s/train_mp3s\373.mp3
# Loaded audio file: train_mp3s/train_mp3s\372.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\374.mp3
# Loaded audio file: train_mp3s/train_mp3s\374.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\375.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\376.mp3
# Loaded audio file: train_mp3s/train_mp3s\375.mp3
# Loaded audio file: train_mp3s/train_mp3s\376.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\377.mp3
# Loaded audio file: train_mp3s/train_mp3s\377.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\378.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\379.mp3
# Loaded audio file: train_mp3s/train_mp3s\379.mp3
# Loaded audio file: train_mp3s/train_mp3s\378.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\380.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\381.mp3
# Loaded audio file: train_mp3s/train_mp3s\380.mp3
# Loaded audio file: train_mp3s/train_mp3s\381.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\382.mp3
# Loaded audio file: train_mp3s/train_mp3s\382.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\383.mp3
# Loaded audio file: train_mp3s/train_mp3s\383.mp3
# Extracted features: (89,)
# Processing file: train_mp3s/train_mp3s\384.mp3
# Loaded audio file: train_mp3s/train_mp3s\384.mp3
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# Extracted features: (89,)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       4 try:
# ----> 5     train_features, train_labels = load_preprocessed_data(folder_path)
#       6     print("Loaded preprocessed data from the 'V5' folder.")
#
# Cell In[7], line 16, in load_preprocessed_data(folder_path)
#      15 def load_preprocessed_data(folder_path):
# ---> 16     with open(os.path.join(folder_path, 'train_features.pkl'), 'rb') as f:
#      17         data = pickle.load(f)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'V5\\train_features.pkl'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       6     print("Loaded preprocessed data from the 'V5' folder.")
#       7 except FileNotFoundError:
# ----> 8     train_features_original = prepare_data('train_mp3s/train_mp3s')
#       9     print(f"Original train features shape: {train_features_original.shape}")
#      11     train_features_augmented = prepare_data('train_mp3s/train_mp3s', augment=True)
#
# Cell In[7], line 102, in prepare_data(directory, augment)
#     100 file_paths = [os.path.join(directory, f"{i}.mp3") for i in range(len(os.listdir(directory)))]
#     101 with ThreadPoolExecutor() as executor:
# --> 102     results = list(executor.map(lambda x: process_file(x, augment), file_paths))
#     103 features = [feat for feat in results if feat is not None]
#     104 print(f"Processed {len(features)} audio files")
#
# File c:\Users\mojii\anaconda3\envs\ML\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File c:\Users\mojii\anaconda3\envs\ML\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File c:\Users\mojii\anaconda3\envs\ML\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\mojii\anaconda3\envs\ML\Lib\threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
# Block 5: Model Training and Prediction
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

if len(train_features) > 0:
    if len(train_features) != len(train_labels):
        raise ValueError("Number of train features and labels do not match.")

    # Standardize the features
    scaler = StandardScaler()
    train_features = scaler.fit_transform(train_features)
    test_features = scaler.transform(test_features)

    # Create a custom dataset class
    class AudioDataset(Dataset):
        def __init__(self, features, labels):
            self.features = torch.tensor(features, dtype=torch.float32)
            self.labels = torch.tensor(labels, dtype=torch.long)

        def __len__(self):
            return len(self.features)

        def __getitem__(self, index):
            return self.features[index], self.labels[index]

    # Set up cross-validation
    num_folds = 10
    kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

    # Initialize variables to store the best model and its metrics
    best_model = None
    best_accuracy = 0.0
    best_f1 = 0.0
    best_precision = 0.0
    best_recall = 0.0

    # Perform cross-validation
    for fold, (train_indices, val_indices) in enumerate(kfold.split(train_features, train_labels), 1):
        print(f"Fold {fold}/{num_folds}")

        # Create data subsets for the current fold
        train_data = train_features[train_indices]
        train_labels_fold = train_labels[train_indices]
        val_data = train_features[val_indices]
        val_labels_fold = train_labels[val_indices]

        # Create PyTorch datasets
        train_dataset = AudioDataset(train_data, train_labels_fold)
        val_dataset = AudioDataset(val_data, val_labels_fold)

        # Create data loaders
        batch_size = 64
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size)

        # Define the model architecture
        model = nn.Sequential(
            nn.Linear(train_features.shape[1], 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.BatchNorm1d(1024),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.BatchNorm1d(512),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.BatchNorm1d(256),
            nn.Linear(256, 4)
        ).to(device)

        # Define the loss function, optimizer, and scheduler
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.001)
        scheduler = CosineAnnealingLR(optimizer, T_max=50, eta_min=1e-6)

        # Train the model
        num_epochs = 200
        for epoch in range(num_epochs):
            model.train()
            for batch_data, batch_labels in train_loader:
                batch_data = batch_data.to(device)
                batch_labels = batch_labels.to(device)

                optimizer.zero_grad()
                outputs = model(batch_data)
                loss = criterion(outputs, batch_labels)
                loss.backward()
                optimizer.step()

            model.eval()
            with torch.no_grad():
                predictions = []
                true_labels = []
                for batch_data, batch_labels in val_loader:
                    batch_data = batch_data.to(device)
                    batch_labels = batch_labels.to(device)

                    outputs = model(batch_data)
                    _, predicted = torch.max(outputs, 1)
                    predictions.extend(predicted.cpu().numpy())
                    true_labels.extend(batch_labels.cpu().numpy())

                accuracy = accuracy_score(true_labels, predictions)
                f1 = f1_score(true_labels, predictions, average='weighted')
                precision = precision_score(true_labels, predictions, average='weighted')
                recall = recall_score(true_labels, predictions, average='weighted')
                print(f"Epoch [{epoch+1}/{num_epochs}], Validation Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")

            scheduler.step()

        # Update the best model if the current model has higher F1 score
        if f1 > best_f1:
            best_model = model
            best_accuracy = accuracy
            best_f1 = f1
            best_precision = precision
            best_recall = recall

    # Evaluate the best model on the test set
    test_features = torch.tensor(test_features, dtype=torch.float32).to(device)
    best_model.eval()
    with torch.no_grad():
        outputs = best_model(test_features)
        _, predicted_labels = torch.max(outputs, 1)
        predicted_labels = label_encoder.inverse_transform(predicted_labels.cpu().numpy())

    submission = pd.DataFrame({'id': range(len(predicted_labels)), 'category': predicted_labels})
    submission.to_csv('submission.csv', index=False)

    print(f"Best model metrics:")
    print(f"Accuracy: {best_accuracy:.4f}")
    print(f"F1 Score: {best_f1:.4f}")
    print(f"Precision: {best_precision:.4f}")
    print(f"Recall: {best_recall:.4f}")

else:
    print("No training features available. Please check the data.")
