# %%
# Block 1: Importing Libraries
import tarfile
import resampy
import pandas as pd
import librosa
import numpy as np
import os
import shutil
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from concurrent.futures import ThreadPoolExecutor

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
else:
    print("No GPU available. Training will run on CPU.")
# Out:
# GPU: NVIDIA GeForce RTX 4080 Laptop GPU is available.

# %%
# Block 2: Extracting Data
def extract_tar(tar_file, target_dir):
    if os.path.exists(target_dir):
        user_input = input(f"The directory '{target_dir}' already exists. Do you want to skip extraction? (y/n): ")
        if user_input.lower() == 'y':
            print(f"Skipping extraction of {tar_file}.")
            return
        else:
            print(f"Overwriting the existing directory '{target_dir}'.")
            shutil.rmtree(target_dir)

    with tarfile.open(tar_file, 'r') as tar:
        tar.extractall(target_dir)

    # Remove residue "._" hidden files from the inner folder
    inner_folder = os.path.join(target_dir, os.path.splitext(os.path.basename(tar_file))[0])
    for root, dirs, files in os.walk(inner_folder):
        for file in files:
            if file.startswith("._"):
                os.remove(os.path.join(root, file))

extract_tar('train_mp3s.tar', 'train_mp3s')
extract_tar('test_mp3s.tar', 'test_mp3s')
train_labels = np.loadtxt('train_label.txt', dtype=int)
train_labels = np.array([int(label) for label in train_labels])
# Out:
# Skipping extraction of train_mp3s.tar.
# Skipping extraction of test_mp3s.tar.

# %%
# Block 3: Preprocessing Functions
def preprocess_audio(file_path):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
        print(f"Loaded audio file: {file_path}")
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_scaled = np.mean(mfccs.T, axis=0)
        print(f"Extracted MFCCs: {mfccs_scaled.shape}")
        return mfccs_scaled
    except Exception as e:
        print(f"Error processing file: {file_path}")
        print(f"Error message: {str(e)}")
        return None

def process_file(file_path):
    print(f"Processing file: {file_path}")
    mfccs = preprocess_audio(file_path)
    return mfccs

def prepare_data(directory):
    file_paths = [os.path.join(directory, f"{i}.mp3") for i in range(len(os.listdir(directory)))]
    with ThreadPoolExecutor() as executor:
        results = list(executor.map(process_file, file_paths))
    features = [mfccs for mfccs in results if mfccs is not None]
    print(f"Processed {len(features)} audio files")
    return np.array(features)

# %%
# Block 4: Preparing Data
train_features_file = 'train_features.pkl'
test_features_file = 'test_features.pkl'

try:
    with open(train_features_file, 'rb') as f:
        train_features = pickle.load(f)
    print("Loaded train features from file.")
except FileNotFoundError:
    train_features = prepare_data('train_mp3s/train_mp3s')
    with open(train_features_file, 'wb') as f:
        pickle.dump(train_features, f)
    print("Saved train features to file.")

try:
    with open(test_features_file, 'rb') as f:
        test_features = pickle.load(f)
    print("Loaded test features from file.")
except FileNotFoundError:
    test_features = prepare_data('test_mp3s/test_mp3s')
    with open(test_features_file, 'wb') as f:
        pickle.dump(test_features, f)
    print("Saved test features to file.")

print(f"Train features shape: {train_features.shape}")
print(f"Test features shape: {test_features.shape}")

train_labels = np.array([int(label) for label in train_labels])
print(f"Train labels shape: {train_labels.shape}")
print(f"Number of training features: {len(train_features)}")
print(f"Number of training labels: {len(train_labels)}")
print(f"Number of test features: {len(test_features)}")

if len(train_features) == 0:
    print("No training features available. Please check the data.")
# Out:
# Loaded train features from file.
# Loaded test features from file.
# Train features shape: (11886, 40)
# Test features shape: (2447, 40)
# Train labels shape: (11886,)
# Number of training features: 11886
# Number of training labels: 11886
# Number of test features: 2447

# %%
torch.cuda.empty_cache()

# Block 5: Model Training and Prediction
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

if len(train_features) > 0:
    if len(train_features) != len(train_labels):
        raise ValueError("Number of train features and labels do not match.")

    train_data, val_data, train_labels, val_labels = train_test_split(train_features, train_labels, test_size=0.3, random_state=42)
    train_data = torch.tensor(train_data, dtype=torch.float32, device=device)
    val_data = torch.tensor(val_data, dtype=torch.float32, device=device)
    train_labels = torch.tensor(train_labels, dtype=torch.long, device=device)
    val_labels = torch.tensor(val_labels, dtype=torch.long, device=device)

    model = nn.Sequential(
        nn.Linear(40, 2048),
        nn.BatchNorm1d(2048),
        nn.ReLU(),
        nn.Dropout(0.8),
        nn.Linear(2048, 1024),
        nn.BatchNorm1d(1024),
        nn.ReLU(),
        nn.Dropout(0.6),
        nn.Linear(1024, 512),
        nn.BatchNorm1d(512),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512, 256),
        nn.BatchNorm1d(256),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(256, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(128, 64),
        nn.BatchNorm1d(64),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(64, 4)
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

    num_epochs =  500
    batch_size = 1024

    train_dataset = torch.utils.data.TensorDataset(train_data, train_labels)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    for epoch in range(num_epochs):
        model.train()
        for batch_data, batch_labels in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_data)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        with torch.no_grad():
            outputs = model(val_data)
            loss = criterion(outputs, val_labels)
            _, predicted = torch.max(outputs, 1)
            accuracy = (predicted == val_labels).float().mean()
            print(f"Epoch [{epoch+1}/{num_epochs}], Validation Loss: {loss.item():.4f}, Validation Accuracy: {accuracy.item():.4f}")
            scheduler.step(loss)

    test_features = torch.tensor(test_features, dtype=torch.float32, device=device)
    torch.save(model.state_dict(), 'trained_model_fINAL.pth')
    model.eval()
    with torch.no_grad():
        outputs = model(test_features)
        _, predicted_labels = torch.max(outputs, 1)
        predicted_labels = predicted_labels.cpu().tolist()

    submission = pd.DataFrame({'id': range(len(predicted_labels)), 'category': predicted_labels})
    submission.to_csv('submission.csv', index=False)

else:
    print("No training features available. Please check the data.")

torch.cuda.empty_cache()
# Out:
# Using device: cuda
# Epoch [1/500], Validation Loss: 1.3625, Validation Accuracy: 0.3404
# Epoch [2/500], Validation Loss: 1.2102, Validation Accuracy: 0.5020
# Epoch [3/500], Validation Loss: 1.0684, Validation Accuracy: 0.5552
# Epoch [4/500], Validation Loss: 1.0010, Validation Accuracy: 0.5830
# Epoch [5/500], Validation Loss: 0.9305, Validation Accuracy: 0.6256
# Epoch [6/500], Validation Loss: 0.8612, Validation Accuracy: 0.6503
# Epoch [7/500], Validation Loss: 0.8046, Validation Accuracy: 0.6618
# Epoch [8/500], Validation Loss: 0.7677, Validation Accuracy: 0.6820
# Epoch [9/500], Validation Loss: 0.7423, Validation Accuracy: 0.6887
# Epoch [10/500], Validation Loss: 0.7265, Validation Accuracy: 0.6991
# Epoch [11/500], Validation Loss: 0.7023, Validation Accuracy: 0.7033
# Epoch [12/500], Validation Loss: 0.6911, Validation Accuracy: 0.7120
# Epoch [13/500], Validation Loss: 0.6824, Validation Accuracy: 0.7156
# Epoch [14/500], Validation Loss: 0.6733, Validation Accuracy: 0.7204
# Epoch [15/500], Validation Loss: 0.6691, Validation Accuracy: 0.7229
# Epoch [16/500], Validation Loss: 0.6643, Validation Accuracy: 0.7221
# Epoch [17/500], Validation Loss: 0.6492, Validation Accuracy: 0.7330
# Epoch [18/500], Validation Loss: 0.6414, Validation Accuracy: 0.7356
# Epoch [19/500], Validation Loss: 0.6434, Validation Accuracy: 0.7350
# Epoch [20/500], Validation Loss: 0.6346, Validation Accuracy: 0.7400
# Epoch [21/500], Validation Loss: 0.6276, Validation Accuracy: 0.7400
# Epoch [22/500], Validation Loss: 0.6258, Validation Accuracy: 0.7431
# Epoch [23/500], Validation Loss: 0.6243, Validation Accuracy: 0.7412
# Epoch [24/500], Validation Loss: 0.6179, Validation Accuracy: 0.7487
# Epoch [25/500], Validation Loss: 0.6116, Validation Accuracy: 0.7490
# Epoch [26/500], Validation Loss: 0.6135, Validation Accuracy: 0.7479
# Epoch [27/500], Validation Loss: 0.6088, Validation Accuracy: 0.7490
# Epoch [28/500], Validation Loss: 0.6041, Validation Accuracy: 0.7518
# Epoch [29/500], Validation Loss: 0.6014, Validation Accuracy: 0.7507
# Epoch [30/500], Validation Loss: 0.6003, Validation Accuracy: 0.7479
# Epoch [31/500], Validation Loss: 0.5926, Validation Accuracy: 0.7493
# Epoch [32/500], Validation Loss: 0.5922, Validation Accuracy: 0.7532
# Epoch [33/500], Validation Loss: 0.5898, Validation Accuracy: 0.7580
# Epoch [34/500], Validation Loss: 0.5855, Validation Accuracy: 0.7586
# Epoch [35/500], Validation Loss: 0.5814, Validation Accuracy: 0.7605
# Epoch [36/500], Validation Loss: 0.5799, Validation Accuracy: 0.7616
# Epoch [37/500], Validation Loss: 0.5781, Validation Accuracy: 0.7611
# Epoch [38/500], Validation Loss: 0.5766, Validation Accuracy: 0.7600
# Epoch [39/500], Validation Loss: 0.5736, Validation Accuracy: 0.7608
# Epoch [40/500], Validation Loss: 0.5758, Validation Accuracy: 0.7577
# Epoch [41/500], Validation Loss: 0.5783, Validation Accuracy: 0.7591
# Epoch [42/500], Validation Loss: 0.5691, Validation Accuracy: 0.7642
# Epoch [43/500], Validation Loss: 0.5687, Validation Accuracy: 0.7656
# Epoch [44/500], Validation Loss: 0.5616, Validation Accuracy: 0.7644
# Epoch [45/500], Validation Loss: 0.5579, Validation Accuracy: 0.7686
# Epoch [46/500], Validation Loss: 0.5582, Validation Accuracy: 0.7647
# Epoch [47/500], Validation Loss: 0.5579, Validation Accuracy: 0.7644
# Epoch [48/500], Validation Loss: 0.5559, Validation Accuracy: 0.7692
# Epoch [49/500], Validation Loss: 0.5525, Validation Accuracy: 0.7647
# Epoch [50/500], Validation Loss: 0.5519, Validation Accuracy: 0.7684
# Epoch [51/500], Validation Loss: 0.5470, Validation Accuracy: 0.7698
# Epoch [52/500], Validation Loss: 0.5439, Validation Accuracy: 0.7729
# Epoch [53/500], Validation Loss: 0.5394, Validation Accuracy: 0.7709
# Epoch [54/500], Validation Loss: 0.5417, Validation Accuracy: 0.7726
# Epoch [55/500], Validation Loss: 0.5428, Validation Accuracy: 0.7731
# Epoch [56/500], Validation Loss: 0.5414, Validation Accuracy: 0.7715
# Epoch [57/500], Validation Loss: 0.5425, Validation Accuracy: 0.7745
# Epoch [58/500], Validation Loss: 0.5363, Validation Accuracy: 0.7726
# Epoch [59/500], Validation Loss: 0.5354, Validation Accuracy: 0.7785
# Epoch [60/500], Validation Loss: 0.5346, Validation Accuracy: 0.7757
# Epoch [61/500], Validation Loss: 0.5348, Validation Accuracy: 0.7765
# Epoch [62/500], Validation Loss: 0.5389, Validation Accuracy: 0.7751
# Epoch [63/500], Validation Loss: 0.5335, Validation Accuracy: 0.7787
# Epoch [64/500], Validation Loss: 0.5277, Validation Accuracy: 0.7771
# Epoch [65/500], Validation Loss: 0.5297, Validation Accuracy: 0.7796
# Epoch [66/500], Validation Loss: 0.5261, Validation Accuracy: 0.7810
# Epoch [67/500], Validation Loss: 0.5302, Validation Accuracy: 0.7782
# Epoch [68/500], Validation Loss: 0.5241, Validation Accuracy: 0.7818
# Epoch [69/500], Validation Loss: 0.5245, Validation Accuracy: 0.7804
# Epoch [70/500], Validation Loss: 0.5219, Validation Accuracy: 0.7813
# Epoch [71/500], Validation Loss: 0.5189, Validation Accuracy: 0.7844
# Epoch [72/500], Validation Loss: 0.5222, Validation Accuracy: 0.7841
# Epoch [73/500], Validation Loss: 0.5153, Validation Accuracy: 0.7872
# Epoch [74/500], Validation Loss: 0.5187, Validation Accuracy: 0.7810
# Epoch [75/500], Validation Loss: 0.5149, Validation Accuracy: 0.7835
# Epoch [76/500], Validation Loss: 0.5113, Validation Accuracy: 0.7880
# Epoch [77/500], Validation Loss: 0.5173, Validation Accuracy: 0.7863
# Epoch [78/500], Validation Loss: 0.5106, Validation Accuracy: 0.7860
# Epoch [79/500], Validation Loss: 0.5094, Validation Accuracy: 0.7872
# Epoch [80/500], Validation Loss: 0.5038, Validation Accuracy: 0.7874
# Epoch [81/500], Validation Loss: 0.5029, Validation Accuracy: 0.7872
# Epoch [82/500], Validation Loss: 0.5019, Validation Accuracy: 0.7925
# Epoch [83/500], Validation Loss: 0.5022, Validation Accuracy: 0.7919
# Epoch [84/500], Validation Loss: 0.5093, Validation Accuracy: 0.7872
# Epoch [85/500], Validation Loss: 0.5058, Validation Accuracy: 0.7925
# Epoch [86/500], Validation Loss: 0.5095, Validation Accuracy: 0.7914
# Epoch [87/500], Validation Loss: 0.5066, Validation Accuracy: 0.7888
# Epoch [88/500], Validation Loss: 0.5065, Validation Accuracy: 0.7914
# Epoch [89/500], Validation Loss: 0.5064, Validation Accuracy: 0.7928
# Epoch [90/500], Validation Loss: 0.5079, Validation Accuracy: 0.7894
# Epoch [91/500], Validation Loss: 0.5013, Validation Accuracy: 0.7914
# Epoch [92/500], Validation Loss: 0.4944, Validation Accuracy: 0.7930
# Epoch [93/500], Validation Loss: 0.4953, Validation Accuracy: 0.7981
# Epoch [94/500], Validation Loss: 0.4937, Validation Accuracy: 0.7953
# Epoch [95/500], Validation Loss: 0.4976, Validation Accuracy: 0.7995
# Epoch [96/500], Validation Loss: 0.4976, Validation Accuracy: 0.7989
# Epoch [97/500], Validation Loss: 0.4917, Validation Accuracy: 0.7981
# Epoch [98/500], Validation Loss: 0.4960, Validation Accuracy: 0.7975
# Epoch [99/500], Validation Loss: 0.4899, Validation Accuracy: 0.7956
# Epoch [100/500], Validation Loss: 0.4925, Validation Accuracy: 0.7981
# Epoch [101/500], Validation Loss: 0.4849, Validation Accuracy: 0.7989
# Epoch [102/500], Validation Loss: 0.4875, Validation Accuracy: 0.8001
# Epoch [103/500], Validation Loss: 0.4884, Validation Accuracy: 0.8009
# Epoch [104/500], Validation Loss: 0.4848, Validation Accuracy: 0.7989
# Epoch [105/500], Validation Loss: 0.4830, Validation Accuracy: 0.8043
# Epoch [106/500], Validation Loss: 0.4792, Validation Accuracy: 0.8048
# Epoch [107/500], Validation Loss: 0.4833, Validation Accuracy: 0.8043
# Epoch [108/500], Validation Loss: 0.4801, Validation Accuracy: 0.8009
# Epoch [109/500], Validation Loss: 0.4850, Validation Accuracy: 0.8003
# Epoch [110/500], Validation Loss: 0.4776, Validation Accuracy: 0.8043
# Epoch [111/500], Validation Loss: 0.4736, Validation Accuracy: 0.8054
# Epoch [112/500], Validation Loss: 0.4791, Validation Accuracy: 0.8065
# Epoch [113/500], Validation Loss: 0.4823, Validation Accuracy: 0.8062
# Epoch [114/500], Validation Loss: 0.4800, Validation Accuracy: 0.8071
# Epoch [115/500], Validation Loss: 0.4801, Validation Accuracy: 0.8054
# Epoch [116/500], Validation Loss: 0.4716, Validation Accuracy: 0.8051
# Epoch [117/500], Validation Loss: 0.4762, Validation Accuracy: 0.8062
# Epoch [118/500], Validation Loss: 0.4704, Validation Accuracy: 0.8079
# Epoch [119/500], Validation Loss: 0.4735, Validation Accuracy: 0.8079
# Epoch [120/500], Validation Loss: 0.4737, Validation Accuracy: 0.8057
# Epoch [121/500], Validation Loss: 0.4740, Validation Accuracy: 0.8090
# Epoch [122/500], Validation Loss: 0.4744, Validation Accuracy: 0.8096
# Epoch [123/500], Validation Loss: 0.4762, Validation Accuracy: 0.8116
# Epoch [124/500], Validation Loss: 0.4719, Validation Accuracy: 0.8102
# Epoch [125/500], Validation Loss: 0.4703, Validation Accuracy: 0.8102
# Epoch [126/500], Validation Loss: 0.4701, Validation Accuracy: 0.8099
# Epoch [127/500], Validation Loss: 0.4707, Validation Accuracy: 0.8090
# Epoch [128/500], Validation Loss: 0.4713, Validation Accuracy: 0.8107
# Epoch [129/500], Validation Loss: 0.4775, Validation Accuracy: 0.8068
# Epoch [130/500], Validation Loss: 0.4651, Validation Accuracy: 0.8087
# Epoch [131/500], Validation Loss: 0.4653, Validation Accuracy: 0.8124
# Epoch [132/500], Validation Loss: 0.4636, Validation Accuracy: 0.8130
# Epoch [133/500], Validation Loss: 0.4622, Validation Accuracy: 0.8130
# Epoch [134/500], Validation Loss: 0.4664, Validation Accuracy: 0.8082
# Epoch [135/500], Validation Loss: 0.4601, Validation Accuracy: 0.8102
# Epoch [136/500], Validation Loss: 0.4578, Validation Accuracy: 0.8116
# Epoch [137/500], Validation Loss: 0.4545, Validation Accuracy: 0.8113
# Epoch [138/500], Validation Loss: 0.4572, Validation Accuracy: 0.8169
# Epoch [139/500], Validation Loss: 0.4548, Validation Accuracy: 0.8152
# Epoch [140/500], Validation Loss: 0.4529, Validation Accuracy: 0.8169
# Epoch [141/500], Validation Loss: 0.4575, Validation Accuracy: 0.8130
# Epoch [142/500], Validation Loss: 0.4570, Validation Accuracy: 0.8118
# Epoch [143/500], Validation Loss: 0.4594, Validation Accuracy: 0.8132
# Epoch [144/500], Validation Loss: 0.4581, Validation Accuracy: 0.8188
# Epoch [145/500], Validation Loss: 0.4594, Validation Accuracy: 0.8158
# Epoch [146/500], Validation Loss: 0.4615, Validation Accuracy: 0.8124
# Epoch [147/500], Validation Loss: 0.4593, Validation Accuracy: 0.8107
# Epoch [148/500], Validation Loss: 0.4585, Validation Accuracy: 0.8155
# Epoch [149/500], Validation Loss: 0.4577, Validation Accuracy: 0.8174
# Epoch [150/500], Validation Loss: 0.4616, Validation Accuracy: 0.8132
# Epoch [151/500], Validation Loss: 0.4600, Validation Accuracy: 0.8158
# Epoch [152/500], Validation Loss: 0.4590, Validation Accuracy: 0.8149
# Epoch [153/500], Validation Loss: 0.4587, Validation Accuracy: 0.8132
# Epoch [154/500], Validation Loss: 0.4575, Validation Accuracy: 0.8138
# Epoch [155/500], Validation Loss: 0.4565, Validation Accuracy: 0.8163
# Epoch [156/500], Validation Loss: 0.4553, Validation Accuracy: 0.8172
# Epoch [157/500], Validation Loss: 0.4545, Validation Accuracy: 0.8160
# Epoch [158/500], Validation Loss: 0.4539, Validation Accuracy: 0.8194
# Epoch [159/500], Validation Loss: 0.4534, Validation Accuracy: 0.8177
# Epoch [160/500], Validation Loss: 0.4534, Validation Accuracy: 0.8144
# Epoch [161/500], Validation Loss: 0.4533, Validation Accuracy: 0.8172
# Epoch [162/500], Validation Loss: 0.4523, Validation Accuracy: 0.8183
# Epoch [163/500], Validation Loss: 0.4520, Validation Accuracy: 0.8174
# Epoch [164/500], Validation Loss: 0.4520, Validation Accuracy: 0.8183
# Epoch [165/500], Validation Loss: 0.4528, Validation Accuracy: 0.8183
# Epoch [166/500], Validation Loss: 0.4530, Validation Accuracy: 0.8160
# Epoch [167/500], Validation Loss: 0.4522, Validation Accuracy: 0.8166
# Epoch [168/500], Validation Loss: 0.4512, Validation Accuracy: 0.8186
# Epoch [169/500], Validation Loss: 0.4502, Validation Accuracy: 0.8211
# Epoch [170/500], Validation Loss: 0.4507, Validation Accuracy: 0.8197
# Epoch [171/500], Validation Loss: 0.4526, Validation Accuracy: 0.8194
# Epoch [172/500], Validation Loss: 0.4536, Validation Accuracy: 0.8174
# Epoch [173/500], Validation Loss: 0.4525, Validation Accuracy: 0.8180
# Epoch [174/500], Validation Loss: 0.4528, Validation Accuracy: 0.8188
# Epoch [175/500], Validation Loss: 0.4527, Validation Accuracy: 0.8197
# Epoch [176/500], Validation Loss: 0.4526, Validation Accuracy: 0.8194
# Epoch [177/500], Validation Loss: 0.4520, Validation Accuracy: 0.8200
# Epoch [178/500], Validation Loss: 0.4518, Validation Accuracy: 0.8205
# Epoch [179/500], Validation Loss: 0.4519, Validation Accuracy: 0.8172
# Epoch [180/500], Validation Loss: 0.4514, Validation Accuracy: 0.8174
# Epoch [181/500], Validation Loss: 0.4503, Validation Accuracy: 0.8197
# Epoch [182/500], Validation Loss: 0.4510, Validation Accuracy: 0.8186
# Epoch [183/500], Validation Loss: 0.4503, Validation Accuracy: 0.8191
# Epoch [184/500], Validation Loss: 0.4517, Validation Accuracy: 0.8188
# Epoch [185/500], Validation Loss: 0.4520, Validation Accuracy: 0.8188
# Epoch [186/500], Validation Loss: 0.4514, Validation Accuracy: 0.8197
# Epoch [187/500], Validation Loss: 0.4506, Validation Accuracy: 0.8188
# Epoch [188/500], Validation Loss: 0.4508, Validation Accuracy: 0.8197
# Epoch [189/500], Validation Loss: 0.4508, Validation Accuracy: 0.8186
# Epoch [190/500], Validation Loss: 0.4502, Validation Accuracy: 0.8191
# Epoch [191/500], Validation Loss: 0.4506, Validation Accuracy: 0.8191
# Epoch [192/500], Validation Loss: 0.4515, Validation Accuracy: 0.8186
# Epoch [193/500], Validation Loss: 0.4507, Validation Accuracy: 0.8183
# Epoch [194/500], Validation Loss: 0.4509, Validation Accuracy: 0.8197
# Epoch [195/500], Validation Loss: 0.4512, Validation Accuracy: 0.8186
# Epoch [196/500], Validation Loss: 0.4512, Validation Accuracy: 0.8183
# Epoch [197/500], Validation Loss: 0.4514, Validation Accuracy: 0.8174
# Epoch [198/500], Validation Loss: 0.4514, Validation Accuracy: 0.8191
# Epoch [199/500], Validation Loss: 0.4520, Validation Accuracy: 0.8200
# Epoch [200/500], Validation Loss: 0.4519, Validation Accuracy: 0.8188
# Epoch [201/500], Validation Loss: 0.4513, Validation Accuracy: 0.8202
# Epoch [202/500], Validation Loss: 0.4504, Validation Accuracy: 0.8188
# Epoch [203/500], Validation Loss: 0.4519, Validation Accuracy: 0.8180
# Epoch [204/500], Validation Loss: 0.4520, Validation Accuracy: 0.8174
# Epoch [205/500], Validation Loss: 0.4509, Validation Accuracy: 0.8194
# Epoch [206/500], Validation Loss: 0.4515, Validation Accuracy: 0.8194
# Epoch [207/500], Validation Loss: 0.4514, Validation Accuracy: 0.8191
# Epoch [208/500], Validation Loss: 0.4515, Validation Accuracy: 0.8180
# Epoch [209/500], Validation Loss: 0.4519, Validation Accuracy: 0.8188
# Epoch [210/500], Validation Loss: 0.4521, Validation Accuracy: 0.8188
# Epoch [211/500], Validation Loss: 0.4521, Validation Accuracy: 0.8186
# Epoch [212/500], Validation Loss: 0.4518, Validation Accuracy: 0.8191
# Epoch [213/500], Validation Loss: 0.4509, Validation Accuracy: 0.8188
# Epoch [214/500], Validation Loss: 0.4524, Validation Accuracy: 0.8200
# Epoch [215/500], Validation Loss: 0.4522, Validation Accuracy: 0.8188
# Epoch [216/500], Validation Loss: 0.4520, Validation Accuracy: 0.8174
# Epoch [217/500], Validation Loss: 0.4517, Validation Accuracy: 0.8186
# Epoch [218/500], Validation Loss: 0.4512, Validation Accuracy: 0.8188
# Epoch [219/500], Validation Loss: 0.4517, Validation Accuracy: 0.8202
# Epoch [220/500], Validation Loss: 0.4516, Validation Accuracy: 0.8197
# Epoch [221/500], Validation Loss: 0.4514, Validation Accuracy: 0.8194
# Epoch [222/500], Validation Loss: 0.4516, Validation Accuracy: 0.8186
# Epoch [223/500], Validation Loss: 0.4511, Validation Accuracy: 0.8197
# Epoch [224/500], Validation Loss: 0.4511, Validation Accuracy: 0.8197
# Epoch [225/500], Validation Loss: 0.4520, Validation Accuracy: 0.8183
# Epoch [226/500], Validation Loss: 0.4513, Validation Accuracy: 0.8191
# Epoch [227/500], Validation Loss: 0.4522, Validation Accuracy: 0.8194
# Epoch [228/500], Validation Loss: 0.4521, Validation Accuracy: 0.8208
# Epoch [229/500], Validation Loss: 0.4524, Validation Accuracy: 0.8188
# Epoch [230/500], Validation Loss: 0.4507, Validation Accuracy: 0.8180
# Epoch [231/500], Validation Loss: 0.4512, Validation Accuracy: 0.8186
# Epoch [232/500], Validation Loss: 0.4517, Validation Accuracy: 0.8183
# Epoch [233/500], Validation Loss: 0.4508, Validation Accuracy: 0.8180
# Epoch [234/500], Validation Loss: 0.4507, Validation Accuracy: 0.8180
# Epoch [235/500], Validation Loss: 0.4512, Validation Accuracy: 0.8177
# Epoch [236/500], Validation Loss: 0.4516, Validation Accuracy: 0.8188
# Epoch [237/500], Validation Loss: 0.4521, Validation Accuracy: 0.8200
# Epoch [238/500], Validation Loss: 0.4521, Validation Accuracy: 0.8188
# Epoch [239/500], Validation Loss: 0.4515, Validation Accuracy: 0.8194
# Epoch [240/500], Validation Loss: 0.4519, Validation Accuracy: 0.8205
# Epoch [241/500], Validation Loss: 0.4517, Validation Accuracy: 0.8172
# Epoch [242/500], Validation Loss: 0.4515, Validation Accuracy: 0.8183
# Epoch [243/500], Validation Loss: 0.4513, Validation Accuracy: 0.8197
# Epoch [244/500], Validation Loss: 0.4517, Validation Accuracy: 0.8191
# Epoch [245/500], Validation Loss: 0.4515, Validation Accuracy: 0.8183
# Epoch [246/500], Validation Loss: 0.4524, Validation Accuracy: 0.8186
# Epoch [247/500], Validation Loss: 0.4523, Validation Accuracy: 0.8186
# Epoch [248/500], Validation Loss: 0.4538, Validation Accuracy: 0.8200
# Epoch [249/500], Validation Loss: 0.4520, Validation Accuracy: 0.8180
# Epoch [250/500], Validation Loss: 0.4521, Validation Accuracy: 0.8183
# Epoch [251/500], Validation Loss: 0.4510, Validation Accuracy: 0.8180
# Epoch [252/500], Validation Loss: 0.4516, Validation Accuracy: 0.8174
# Epoch [253/500], Validation Loss: 0.4508, Validation Accuracy: 0.8200
# Epoch [254/500], Validation Loss: 0.4511, Validation Accuracy: 0.8202
# Epoch [255/500], Validation Loss: 0.4511, Validation Accuracy: 0.8191
# Epoch [256/500], Validation Loss: 0.4518, Validation Accuracy: 0.8188
# Epoch [257/500], Validation Loss: 0.4518, Validation Accuracy: 0.8191
# Epoch [258/500], Validation Loss: 0.4513, Validation Accuracy: 0.8194
# Epoch [259/500], Validation Loss: 0.4506, Validation Accuracy: 0.8174
# Epoch [260/500], Validation Loss: 0.4514, Validation Accuracy: 0.8183
# Epoch [261/500], Validation Loss: 0.4521, Validation Accuracy: 0.8180
# Epoch [262/500], Validation Loss: 0.4522, Validation Accuracy: 0.8183
# Epoch [263/500], Validation Loss: 0.4516, Validation Accuracy: 0.8183
# Epoch [264/500], Validation Loss: 0.4517, Validation Accuracy: 0.8197
# Epoch [265/500], Validation Loss: 0.4512, Validation Accuracy: 0.8197
# Epoch [266/500], Validation Loss: 0.4516, Validation Accuracy: 0.8188
# Epoch [267/500], Validation Loss: 0.4506, Validation Accuracy: 0.8197
# Epoch [268/500], Validation Loss: 0.4508, Validation Accuracy: 0.8197
# Epoch [269/500], Validation Loss: 0.4518, Validation Accuracy: 0.8205
# Epoch [270/500], Validation Loss: 0.4500, Validation Accuracy: 0.8197
# Epoch [271/500], Validation Loss: 0.4508, Validation Accuracy: 0.8180
# Epoch [272/500], Validation Loss: 0.4514, Validation Accuracy: 0.8172
# Epoch [273/500], Validation Loss: 0.4509, Validation Accuracy: 0.8186
# Epoch [274/500], Validation Loss: 0.4528, Validation Accuracy: 0.8183
# Epoch [275/500], Validation Loss: 0.4522, Validation Accuracy: 0.8177
# Epoch [276/500], Validation Loss: 0.4515, Validation Accuracy: 0.8186
# Epoch [277/500], Validation Loss: 0.4515, Validation Accuracy: 0.8180
# Epoch [278/500], Validation Loss: 0.4520, Validation Accuracy: 0.8188
# Epoch [279/500], Validation Loss: 0.4517, Validation Accuracy: 0.8197
# Epoch [280/500], Validation Loss: 0.4514, Validation Accuracy: 0.8169
# Epoch [281/500], Validation Loss: 0.4515, Validation Accuracy: 0.8174
# Epoch [282/500], Validation Loss: 0.4505, Validation Accuracy: 0.8216
# Epoch [283/500], Validation Loss: 0.4508, Validation Accuracy: 0.8197
# Epoch [284/500], Validation Loss: 0.4516, Validation Accuracy: 0.8202
# Epoch [285/500], Validation Loss: 0.4522, Validation Accuracy: 0.8194
# Epoch [286/500], Validation Loss: 0.4522, Validation Accuracy: 0.8188
# Epoch [287/500], Validation Loss: 0.4517, Validation Accuracy: 0.8197
# Epoch [288/500], Validation Loss: 0.4518, Validation Accuracy: 0.8197
# Epoch [289/500], Validation Loss: 0.4524, Validation Accuracy: 0.8194
# Epoch [290/500], Validation Loss: 0.4519, Validation Accuracy: 0.8194
# Epoch [291/500], Validation Loss: 0.4525, Validation Accuracy: 0.8174
# Epoch [292/500], Validation Loss: 0.4521, Validation Accuracy: 0.8177
# Epoch [293/500], Validation Loss: 0.4519, Validation Accuracy: 0.8183
# Epoch [294/500], Validation Loss: 0.4513, Validation Accuracy: 0.8180
# Epoch [295/500], Validation Loss: 0.4519, Validation Accuracy: 0.8194
# Epoch [296/500], Validation Loss: 0.4520, Validation Accuracy: 0.8200
# Epoch [297/500], Validation Loss: 0.4513, Validation Accuracy: 0.8200
# Epoch [298/500], Validation Loss: 0.4510, Validation Accuracy: 0.8183
# Epoch [299/500], Validation Loss: 0.4515, Validation Accuracy: 0.8191
# Epoch [300/500], Validation Loss: 0.4518, Validation Accuracy: 0.8200
# Epoch [301/500], Validation Loss: 0.4521, Validation Accuracy: 0.8200
# Epoch [302/500], Validation Loss: 0.4525, Validation Accuracy: 0.8211
# Epoch [303/500], Validation Loss: 0.4518, Validation Accuracy: 0.8177
# Epoch [304/500], Validation Loss: 0.4524, Validation Accuracy: 0.8191
# Epoch [305/500], Validation Loss: 0.4517, Validation Accuracy: 0.8172
# Epoch [306/500], Validation Loss: 0.4515, Validation Accuracy: 0.8183
# Epoch [307/500], Validation Loss: 0.4507, Validation Accuracy: 0.8183
# Epoch [308/500], Validation Loss: 0.4502, Validation Accuracy: 0.8191
# Epoch [309/500], Validation Loss: 0.4503, Validation Accuracy: 0.8197
# Epoch [310/500], Validation Loss: 0.4507, Validation Accuracy: 0.8194
# Epoch [311/500], Validation Loss: 0.4516, Validation Accuracy: 0.8180
# Epoch [312/500], Validation Loss: 0.4514, Validation Accuracy: 0.8172
# Epoch [313/500], Validation Loss: 0.4510, Validation Accuracy: 0.8183
# Epoch [314/500], Validation Loss: 0.4514, Validation Accuracy: 0.8194
# Epoch [315/500], Validation Loss: 0.4515, Validation Accuracy: 0.8180
# Epoch [316/500], Validation Loss: 0.4516, Validation Accuracy: 0.8183
# Epoch [317/500], Validation Loss: 0.4526, Validation Accuracy: 0.8188
# Epoch [318/500], Validation Loss: 0.4521, Validation Accuracy: 0.8188
# Epoch [319/500], Validation Loss: 0.4521, Validation Accuracy: 0.8194
# Epoch [320/500], Validation Loss: 0.4518, Validation Accuracy: 0.8188
# Epoch [321/500], Validation Loss: 0.4515, Validation Accuracy: 0.8211
# Epoch [322/500], Validation Loss: 0.4532, Validation Accuracy: 0.8197
# Epoch [323/500], Validation Loss: 0.4519, Validation Accuracy: 0.8214
# Epoch [324/500], Validation Loss: 0.4524, Validation Accuracy: 0.8200
# Epoch [325/500], Validation Loss: 0.4523, Validation Accuracy: 0.8200
# Epoch [326/500], Validation Loss: 0.4524, Validation Accuracy: 0.8208
# Epoch [327/500], Validation Loss: 0.4518, Validation Accuracy: 0.8191
# Epoch [328/500], Validation Loss: 0.4530, Validation Accuracy: 0.8186
# Epoch [329/500], Validation Loss: 0.4516, Validation Accuracy: 0.8186
# Epoch [330/500], Validation Loss: 0.4510, Validation Accuracy: 0.8191
# Epoch [331/500], Validation Loss: 0.4517, Validation Accuracy: 0.8194
# Epoch [332/500], Validation Loss: 0.4511, Validation Accuracy: 0.8183
# Epoch [333/500], Validation Loss: 0.4512, Validation Accuracy: 0.8186
# Epoch [334/500], Validation Loss: 0.4512, Validation Accuracy: 0.8194
# Epoch [335/500], Validation Loss: 0.4512, Validation Accuracy: 0.8194
# Epoch [336/500], Validation Loss: 0.4511, Validation Accuracy: 0.8205
# Epoch [337/500], Validation Loss: 0.4507, Validation Accuracy: 0.8194
# Epoch [338/500], Validation Loss: 0.4510, Validation Accuracy: 0.8208
# Epoch [339/500], Validation Loss: 0.4519, Validation Accuracy: 0.8200
# Epoch [340/500], Validation Loss: 0.4515, Validation Accuracy: 0.8186
# Epoch [341/500], Validation Loss: 0.4515, Validation Accuracy: 0.8183
# Epoch [342/500], Validation Loss: 0.4509, Validation Accuracy: 0.8188
# Epoch [343/500], Validation Loss: 0.4511, Validation Accuracy: 0.8197
# Epoch [344/500], Validation Loss: 0.4515, Validation Accuracy: 0.8183
# Epoch [345/500], Validation Loss: 0.4518, Validation Accuracy: 0.8191
# Epoch [346/500], Validation Loss: 0.4509, Validation Accuracy: 0.8197
# Epoch [347/500], Validation Loss: 0.4509, Validation Accuracy: 0.8183
# Epoch [348/500], Validation Loss: 0.4512, Validation Accuracy: 0.8188
# Epoch [349/500], Validation Loss: 0.4517, Validation Accuracy: 0.8183
# Epoch [350/500], Validation Loss: 0.4506, Validation Accuracy: 0.8191
# Epoch [351/500], Validation Loss: 0.4506, Validation Accuracy: 0.8202
# Epoch [352/500], Validation Loss: 0.4510, Validation Accuracy: 0.8197
# Epoch [353/500], Validation Loss: 0.4520, Validation Accuracy: 0.8177
# Epoch [354/500], Validation Loss: 0.4514, Validation Accuracy: 0.8188
# Epoch [355/500], Validation Loss: 0.4515, Validation Accuracy: 0.8186
# Epoch [356/500], Validation Loss: 0.4517, Validation Accuracy: 0.8191
# Epoch [357/500], Validation Loss: 0.4519, Validation Accuracy: 0.8180
# Epoch [358/500], Validation Loss: 0.4514, Validation Accuracy: 0.8191
# Epoch [359/500], Validation Loss: 0.4520, Validation Accuracy: 0.8188
# Epoch [360/500], Validation Loss: 0.4521, Validation Accuracy: 0.8188
# Epoch [361/500], Validation Loss: 0.4507, Validation Accuracy: 0.8186
# Epoch [362/500], Validation Loss: 0.4516, Validation Accuracy: 0.8183
# Epoch [363/500], Validation Loss: 0.4519, Validation Accuracy: 0.8183
# Epoch [364/500], Validation Loss: 0.4528, Validation Accuracy: 0.8180
# Epoch [365/500], Validation Loss: 0.4517, Validation Accuracy: 0.8191
# Epoch [366/500], Validation Loss: 0.4529, Validation Accuracy: 0.8194
# Epoch [367/500], Validation Loss: 0.4526, Validation Accuracy: 0.8186
# Epoch [368/500], Validation Loss: 0.4512, Validation Accuracy: 0.8194
# Epoch [369/500], Validation Loss: 0.4509, Validation Accuracy: 0.8205
# Epoch [370/500], Validation Loss: 0.4505, Validation Accuracy: 0.8188
# Epoch [371/500], Validation Loss: 0.4510, Validation Accuracy: 0.8186
# Epoch [372/500], Validation Loss: 0.4511, Validation Accuracy: 0.8186
# Epoch [373/500], Validation Loss: 0.4509, Validation Accuracy: 0.8180
# Epoch [374/500], Validation Loss: 0.4513, Validation Accuracy: 0.8177
# Epoch [375/500], Validation Loss: 0.4520, Validation Accuracy: 0.8208
# Epoch [376/500], Validation Loss: 0.4515, Validation Accuracy: 0.8197
# Epoch [377/500], Validation Loss: 0.4515, Validation Accuracy: 0.8208
# Epoch [378/500], Validation Loss: 0.4516, Validation Accuracy: 0.8191
# Epoch [379/500], Validation Loss: 0.4510, Validation Accuracy: 0.8188
# Epoch [380/500], Validation Loss: 0.4510, Validation Accuracy: 0.8205
# Epoch [381/500], Validation Loss: 0.4512, Validation Accuracy: 0.8183
# Epoch [382/500], Validation Loss: 0.4513, Validation Accuracy: 0.8174
# Epoch [383/500], Validation Loss: 0.4518, Validation Accuracy: 0.8194
# Epoch [384/500], Validation Loss: 0.4517, Validation Accuracy: 0.8188
# Epoch [385/500], Validation Loss: 0.4512, Validation Accuracy: 0.8214
# Epoch [386/500], Validation Loss: 0.4517, Validation Accuracy: 0.8214
# Epoch [387/500], Validation Loss: 0.4519, Validation Accuracy: 0.8216
# Epoch [388/500], Validation Loss: 0.4515, Validation Accuracy: 0.8200
# Epoch [389/500], Validation Loss: 0.4509, Validation Accuracy: 0.8194
# Epoch [390/500], Validation Loss: 0.4513, Validation Accuracy: 0.8194
# Epoch [391/500], Validation Loss: 0.4516, Validation Accuracy: 0.8188
# Epoch [392/500], Validation Loss: 0.4521, Validation Accuracy: 0.8194
# Epoch [393/500], Validation Loss: 0.4528, Validation Accuracy: 0.8191
# Epoch [394/500], Validation Loss: 0.4525, Validation Accuracy: 0.8186
# Epoch [395/500], Validation Loss: 0.4524, Validation Accuracy: 0.8177
# Epoch [396/500], Validation Loss: 0.4514, Validation Accuracy: 0.8197
# Epoch [397/500], Validation Loss: 0.4510, Validation Accuracy: 0.8188
# Epoch [398/500], Validation Loss: 0.4508, Validation Accuracy: 0.8208
# Epoch [399/500], Validation Loss: 0.4509, Validation Accuracy: 0.8191
# Epoch [400/500], Validation Loss: 0.4507, Validation Accuracy: 0.8191
# Epoch [401/500], Validation Loss: 0.4516, Validation Accuracy: 0.8174
# Epoch [402/500], Validation Loss: 0.4504, Validation Accuracy: 0.8177
# Epoch [403/500], Validation Loss: 0.4509, Validation Accuracy: 0.8177
# Epoch [404/500], Validation Loss: 0.4507, Validation Accuracy: 0.8188
# Epoch [405/500], Validation Loss: 0.4519, Validation Accuracy: 0.8177
# Epoch [406/500], Validation Loss: 0.4521, Validation Accuracy: 0.8177
# Epoch [407/500], Validation Loss: 0.4523, Validation Accuracy: 0.8188
# Epoch [408/500], Validation Loss: 0.4527, Validation Accuracy: 0.8183
# Epoch [409/500], Validation Loss: 0.4520, Validation Accuracy: 0.8197
# Epoch [410/500], Validation Loss: 0.4514, Validation Accuracy: 0.8200
# Epoch [411/500], Validation Loss: 0.4506, Validation Accuracy: 0.8208
# Epoch [412/500], Validation Loss: 0.4513, Validation Accuracy: 0.8183
# Epoch [413/500], Validation Loss: 0.4516, Validation Accuracy: 0.8188
# Epoch [414/500], Validation Loss: 0.4513, Validation Accuracy: 0.8194
# Epoch [415/500], Validation Loss: 0.4516, Validation Accuracy: 0.8197
# Epoch [416/500], Validation Loss: 0.4515, Validation Accuracy: 0.8191
# Epoch [417/500], Validation Loss: 0.4516, Validation Accuracy: 0.8180
# Epoch [418/500], Validation Loss: 0.4508, Validation Accuracy: 0.8180
# Epoch [419/500], Validation Loss: 0.4520, Validation Accuracy: 0.8188
# Epoch [420/500], Validation Loss: 0.4517, Validation Accuracy: 0.8177
# Epoch [421/500], Validation Loss: 0.4524, Validation Accuracy: 0.8197
# Epoch [422/500], Validation Loss: 0.4512, Validation Accuracy: 0.8202
# Epoch [423/500], Validation Loss: 0.4517, Validation Accuracy: 0.8188
# Epoch [424/500], Validation Loss: 0.4514, Validation Accuracy: 0.8188
# Epoch [425/500], Validation Loss: 0.4519, Validation Accuracy: 0.8191
# Epoch [426/500], Validation Loss: 0.4521, Validation Accuracy: 0.8186
# Epoch [427/500], Validation Loss: 0.4529, Validation Accuracy: 0.8183
# Epoch [428/500], Validation Loss: 0.4519, Validation Accuracy: 0.8188
# Epoch [429/500], Validation Loss: 0.4509, Validation Accuracy: 0.8188
# Epoch [430/500], Validation Loss: 0.4504, Validation Accuracy: 0.8188
# Epoch [431/500], Validation Loss: 0.4513, Validation Accuracy: 0.8191
# Epoch [432/500], Validation Loss: 0.4510, Validation Accuracy: 0.8188
# Epoch [433/500], Validation Loss: 0.4513, Validation Accuracy: 0.8202
# Epoch [434/500], Validation Loss: 0.4524, Validation Accuracy: 0.8169
# Epoch [435/500], Validation Loss: 0.4513, Validation Accuracy: 0.8188
# Epoch [436/500], Validation Loss: 0.4512, Validation Accuracy: 0.8183
# Epoch [437/500], Validation Loss: 0.4514, Validation Accuracy: 0.8191
# Epoch [438/500], Validation Loss: 0.4514, Validation Accuracy: 0.8205
# Epoch [439/500], Validation Loss: 0.4515, Validation Accuracy: 0.8188
# Epoch [440/500], Validation Loss: 0.4517, Validation Accuracy: 0.8191
# Epoch [441/500], Validation Loss: 0.4513, Validation Accuracy: 0.8197
# Epoch [442/500], Validation Loss: 0.4509, Validation Accuracy: 0.8202
# Epoch [443/500], Validation Loss: 0.4525, Validation Accuracy: 0.8191
# Epoch [444/500], Validation Loss: 0.4520, Validation Accuracy: 0.8197
# Epoch [445/500], Validation Loss: 0.4515, Validation Accuracy: 0.8191
# Epoch [446/500], Validation Loss: 0.4516, Validation Accuracy: 0.8205
# Epoch [447/500], Validation Loss: 0.4520, Validation Accuracy: 0.8202
# Epoch [448/500], Validation Loss: 0.4512, Validation Accuracy: 0.8200
# Epoch [449/500], Validation Loss: 0.4515, Validation Accuracy: 0.8186
# Epoch [450/500], Validation Loss: 0.4512, Validation Accuracy: 0.8191
# Epoch [451/500], Validation Loss: 0.4516, Validation Accuracy: 0.8186
# Epoch [452/500], Validation Loss: 0.4523, Validation Accuracy: 0.8188
# Epoch [453/500], Validation Loss: 0.4516, Validation Accuracy: 0.8194
# Epoch [454/500], Validation Loss: 0.4510, Validation Accuracy: 0.8194
# Epoch [455/500], Validation Loss: 0.4508, Validation Accuracy: 0.8186
# Epoch [456/500], Validation Loss: 0.4506, Validation Accuracy: 0.8200
# Epoch [457/500], Validation Loss: 0.4497, Validation Accuracy: 0.8188
# Epoch [458/500], Validation Loss: 0.4505, Validation Accuracy: 0.8191
# Epoch [459/500], Validation Loss: 0.4512, Validation Accuracy: 0.8208
# Epoch [460/500], Validation Loss: 0.4516, Validation Accuracy: 0.8194
# Epoch [461/500], Validation Loss: 0.4516, Validation Accuracy: 0.8188
# Epoch [462/500], Validation Loss: 0.4520, Validation Accuracy: 0.8191
# Epoch [463/500], Validation Loss: 0.4519, Validation Accuracy: 0.8205
# Epoch [464/500], Validation Loss: 0.4516, Validation Accuracy: 0.8188
# Epoch [465/500], Validation Loss: 0.4520, Validation Accuracy: 0.8197
# Epoch [466/500], Validation Loss: 0.4510, Validation Accuracy: 0.8186
# Epoch [467/500], Validation Loss: 0.4512, Validation Accuracy: 0.8202
# Epoch [468/500], Validation Loss: 0.4511, Validation Accuracy: 0.8188
# Epoch [469/500], Validation Loss: 0.4515, Validation Accuracy: 0.8177
# Epoch [470/500], Validation Loss: 0.4513, Validation Accuracy: 0.8194
# Epoch [471/500], Validation Loss: 0.4517, Validation Accuracy: 0.8183
# Epoch [472/500], Validation Loss: 0.4516, Validation Accuracy: 0.8183
# Epoch [473/500], Validation Loss: 0.4519, Validation Accuracy: 0.8188
# Epoch [474/500], Validation Loss: 0.4510, Validation Accuracy: 0.8177
# Epoch [475/500], Validation Loss: 0.4509, Validation Accuracy: 0.8188
# Epoch [476/500], Validation Loss: 0.4509, Validation Accuracy: 0.8174
# Epoch [477/500], Validation Loss: 0.4514, Validation Accuracy: 0.8197
# Epoch [478/500], Validation Loss: 0.4516, Validation Accuracy: 0.8188
# Epoch [479/500], Validation Loss: 0.4511, Validation Accuracy: 0.8191
# Epoch [480/500], Validation Loss: 0.4517, Validation Accuracy: 0.8197
# Epoch [481/500], Validation Loss: 0.4525, Validation Accuracy: 0.8191
# Epoch [482/500], Validation Loss: 0.4524, Validation Accuracy: 0.8183
# Epoch [483/500], Validation Loss: 0.4519, Validation Accuracy: 0.8191
# Epoch [484/500], Validation Loss: 0.4518, Validation Accuracy: 0.8188
# Epoch [485/500], Validation Loss: 0.4512, Validation Accuracy: 0.8183
# Epoch [486/500], Validation Loss: 0.4513, Validation Accuracy: 0.8186
# Epoch [487/500], Validation Loss: 0.4519, Validation Accuracy: 0.8191
# Epoch [488/500], Validation Loss: 0.4528, Validation Accuracy: 0.8194
# Epoch [489/500], Validation Loss: 0.4517, Validation Accuracy: 0.8197
# Epoch [490/500], Validation Loss: 0.4513, Validation Accuracy: 0.8186
# Epoch [491/500], Validation Loss: 0.4512, Validation Accuracy: 0.8200
# Epoch [492/500], Validation Loss: 0.4508, Validation Accuracy: 0.8194
# Epoch [493/500], Validation Loss: 0.4509, Validation Accuracy: 0.8188
# Epoch [494/500], Validation Loss: 0.4511, Validation Accuracy: 0.8200
# Epoch [495/500], Validation Loss: 0.4513, Validation Accuracy: 0.8208
# Epoch [496/500], Validation Loss: 0.4511, Validation Accuracy: 0.8183
# Epoch [497/500], Validation Loss: 0.4516, Validation Accuracy: 0.8197
# Epoch [498/500], Validation Loss: 0.4510, Validation Accuracy: 0.8200
# Epoch [499/500], Validation Loss: 0.4510, Validation Accuracy: 0.8191
# Epoch [500/500], Validation Loss: 0.4512, Validation Accuracy: 0.8197
